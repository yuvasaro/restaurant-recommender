# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tabulate

from rec_sys import build_user_item_networks, build_model, scale_data, predict_ratings
from utils import load_data, encode_features, get_restaurant_names_cuisines
from constants import *

# %% [markdown]
# ### 1. Load training data into matrices

# %%
# Load data into matrices
user_data, user_vectors, restaurant_data, restaurant_vectors, y_data, num_users, num_restaurants = load_data()

# Scale data with sklearn scalers
y_data, y_scaler = scale_data(y_data.reshape(-1, 1), 'minmax')

# Train test split (identical shuffle needed to keep training examples matched)
user_train      , user_test       = train_test_split(user_data      , train_size=0.8, shuffle=True, random_state=1)
restaurant_train, restaurant_test = train_test_split(restaurant_data, train_size=0.8, shuffle=True, random_state=1)
y_train         , y_test          = train_test_split(y_data         , train_size=0.8, shuffle=True, random_state=1)

print(f"user_train: {user_train.shape}, user_test: {user_test.shape}")
print(f"restaurant_train: {restaurant_train.shape}, restaurant_test: {restaurant_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")
print(f"num_users: {num_users}")
print(f"num_restaurants: {num_restaurants}")
# Out:
# user_train: (928, 12), user_test: (233, 12)
# restaurant_train: (928, 9), restaurant_test: (233, 9)
# y_train: (928, 1), y_test: (233, 1)
# num_users: 138
# num_restaurants: 130

# %% [markdown]
# ### 2. Build neural networks

# %%
layer_units = [
    64, # Dense, relu
    32, # Dense, relu
    16  # Dense, linear
]

user_NN, item_NN = build_user_item_networks(layer_units)

num_user_features = user_data.shape[1] - 1 # subtract 1 for id column
num_restaurant_features = restaurant_data.shape[1] - 1

model = build_model(user_NN, item_NN, num_user_features, num_restaurant_features)
print(model.summary())
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 11)]                 0         []
#
#  input_2 (InputLayer)        [(None, 8)]                  0         []
#
#  sequential (Sequential)     (None, 16)                   3376      ['input_1[0][0]']
#
#  sequential_1 (Sequential)   (None, 16)                   3184      ['input_2[0][0]']
#
#  tf.math.l2_normalize (TFOp  (None, 16)                   0         ['sequential[0][0]']
#  Lambda)
#
#  tf.math.l2_normalize_1 (TF  (None, 16)                   0         ['sequential_1[0][0]']
#  OpLambda)
#
#  dot (Dot)                   (None, 1)                    0         ['tf.math.l2_normalize[0][0]',
#                                                                      'tf.math.l2_normalize_1[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 6560 (25.62 KB)
# Trainable params: 6560 (25.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ### 3. Train the model

# %%
model.fit([user_train[:, 1:], restaurant_train[:, 1:]], y_train, epochs=100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 0s 822us/step - loss: 0.1627
# Epoch 2/100
# 29/29 [==============================] - 0s 727us/step - loss: 0.1407
# Epoch 3/100
# 29/29 [==============================] - 0s 694us/step - loss: 0.1408
# Epoch 4/100
# 29/29 [==============================] - 0s 631us/step - loss: 0.1445
# Epoch 5/100
# 29/29 [==============================] - 0s 618us/step - loss: 0.1367
# Epoch 6/100
# 29/29 [==============================] - 0s 621us/step - loss: 0.1408
# Epoch 7/100
# 29/29 [==============================] - 0s 610us/step - loss: 0.1328
# Epoch 8/100
# 29/29 [==============================] - 0s 649us/step - loss: 0.1380
# Epoch 9/100
# 29/29 [==============================] - 0s 671us/step - loss: 0.1328
# Epoch 10/100
# 29/29 [==============================] - 0s 637us/step - loss: 0.1328
# Epoch 11/100
# 29/29 [==============================] - 0s 662us/step - loss: 0.1347
# Epoch 12/100
# 29/29 [==============================] - 0s 647us/step - loss: 0.1322
# Epoch 13/100
# 29/29 [==============================] - 0s 672us/step - loss: 0.1319
# Epoch 14/100
# 29/29 [==============================] - 0s 671us/step - loss: 0.1317
# Epoch 15/100
# 29/29 [==============================] - 0s 608us/step - loss: 0.1269
# Epoch 16/100
# 29/29 [==============================] - 0s 603us/step - loss: 0.1227
# Epoch 17/100
# 29/29 [==============================] - 0s 642us/step - loss: 0.1217
# Epoch 18/100
# 29/29 [==============================] - 0s 628us/step - loss: 0.1224
# Epoch 19/100
# 29/29 [==============================] - 0s 629us/step - loss: 0.1207
# Epoch 20/100
# 29/29 [==============================] - 0s 616us/step - loss: 0.1284
# Epoch 21/100
# 29/29 [==============================] - 0s 604us/step - loss: 0.1268
# Epoch 22/100
# 29/29 [==============================] - 0s 589us/step - loss: 0.1230
# Epoch 23/100
# 29/29 [==============================] - 0s 596us/step - loss: 0.1170
# Epoch 24/100
# 29/29 [==============================] - 0s 600us/step - loss: 0.1156
# Epoch 25/100
# 29/29 [==============================] - 0s 607us/step - loss: 0.1140
# Epoch 26/100
# 29/29 [==============================] - 0s 618us/step - loss: 0.1131
# Epoch 27/100
# 29/29 [==============================] - 0s 602us/step - loss: 0.1094
# Epoch 28/100
# 29/29 [==============================] - 0s 638us/step - loss: 0.1131
# Epoch 29/100
# 29/29 [==============================] - 0s 626us/step - loss: 0.1083
# Epoch 30/100
# 29/29 [==============================] - 0s 643us/step - loss: 0.1064
# Epoch 31/100
# 29/29 [==============================] - 0s 645us/step - loss: 0.1128
# Epoch 32/100
# 29/29 [==============================] - 0s 614us/step - loss: 0.1132
# Epoch 33/100
# 29/29 [==============================] - 0s 638us/step - loss: 0.1084
# Epoch 34/100
# 29/29 [==============================] - 0s 650us/step - loss: 0.1135
# Epoch 35/100
# 29/29 [==============================] - 0s 664us/step - loss: 0.1050
# Epoch 36/100
# 29/29 [==============================] - 0s 650us/step - loss: 0.1017
# Epoch 37/100
# 29/29 [==============================] - 0s 656us/step - loss: 0.1023
# Epoch 38/100
# 29/29 [==============================] - 0s 714us/step - loss: 0.1018
# Epoch 39/100
# 29/29 [==============================] - 0s 720us/step - loss: 0.1019
# Epoch 40/100
# 29/29 [==============================] - 0s 708us/step - loss: 0.0993
# Epoch 41/100
# 29/29 [==============================] - 0s 707us/step - loss: 0.0949
# Epoch 42/100
# 29/29 [==============================] - 0s 652us/step - loss: 0.0974
# Epoch 43/100
# 29/29 [==============================] - 0s 686us/step - loss: 0.0930
# Epoch 44/100
# 29/29 [==============================] - 0s 652us/step - loss: 0.0931
# Epoch 45/100
# 29/29 [==============================] - 0s 654us/step - loss: 0.0930
# Epoch 46/100
# 29/29 [==============================] - 0s 653us/step - loss: 0.0940
# Epoch 47/100
# 29/29 [==============================] - 0s 791us/step - loss: 0.0894
# Epoch 48/100
# 29/29 [==============================] - 0s 719us/step - loss: 0.0903
# Epoch 49/100
# 29/29 [==============================] - 0s 732us/step - loss: 0.0893
# Epoch 50/100
# 29/29 [==============================] - 0s 689us/step - loss: 0.0873
# Epoch 51/100
# 29/29 [==============================] - 0s 665us/step - loss: 0.0861
# Epoch 52/100
# 29/29 [==============================] - 0s 662us/step - loss: 0.0893
# Epoch 53/100
# 29/29 [==============================] - 0s 680us/step - loss: 0.0870
# Epoch 54/100
# 29/29 [==============================] - 0s 693us/step - loss: 0.0820
# Epoch 55/100
# 29/29 [==============================] - 0s 626us/step - loss: 0.0830
# Epoch 56/100
# 29/29 [==============================] - 0s 658us/step - loss: 0.0836
# Epoch 57/100
# 29/29 [==============================] - 0s 682us/step - loss: 0.0833
# Epoch 58/100
# 29/29 [==============================] - 0s 622us/step - loss: 0.0836
# Epoch 59/100
# 29/29 [==============================] - 0s 689us/step - loss: 0.0888
# Epoch 60/100
# 29/29 [==============================] - 0s 668us/step - loss: 0.0830
# Epoch 61/100
# 29/29 [==============================] - 0s 672us/step - loss: 0.0765
# Epoch 62/100
# 29/29 [==============================] - 0s 698us/step - loss: 0.0758
# Epoch 63/100
# 29/29 [==============================] - 0s 692us/step - loss: 0.0775
# Epoch 64/100
# 29/29 [==============================] - 0s 645us/step - loss: 0.0789
# Epoch 65/100
# 29/29 [==============================] - 0s 670us/step - loss: 0.0750
# Epoch 66/100
# 29/29 [==============================] - 0s 635us/step - loss: 0.0721
# Epoch 67/100
# 29/29 [==============================] - 0s 633us/step - loss: 0.0771
# Epoch 68/100
# 29/29 [==============================] - 0s 670us/step - loss: 0.0799
# Epoch 69/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0753
# Epoch 70/100
# 29/29 [==============================] - 0s 676us/step - loss: 0.0760
# Epoch 71/100
# 29/29 [==============================] - 0s 621us/step - loss: 0.0792
# Epoch 72/100
# 29/29 [==============================] - 0s 640us/step - loss: 0.0770
# Epoch 73/100
# 29/29 [==============================] - 0s 667us/step - loss: 0.0778
# Epoch 74/100
# 29/29 [==============================] - 0s 625us/step - loss: 0.0741
# Epoch 75/100
# 29/29 [==============================] - 0s 619us/step - loss: 0.0810
# Epoch 76/100
# 29/29 [==============================] - 0s 670us/step - loss: 0.0850
# Epoch 77/100
# 29/29 [==============================] - 0s 685us/step - loss: 0.0747
# Epoch 78/100
# 29/29 [==============================] - 0s 662us/step - loss: 0.0725
# Epoch 79/100
# 29/29 [==============================] - 0s 618us/step - loss: 0.0734
# Epoch 80/100
# 29/29 [==============================] - 0s 619us/step - loss: 0.0696
# Epoch 81/100
# 29/29 [==============================] - 0s 619us/step - loss: 0.0688
# Epoch 82/100
# 29/29 [==============================] - 0s 618us/step - loss: 0.0702
# Epoch 83/100
# 29/29 [==============================] - 0s 629us/step - loss: 0.0714
# Epoch 84/100
# 29/29 [==============================] - 0s 607us/step - loss: 0.0663
# Epoch 85/100
# 29/29 [==============================] - 0s 622us/step - loss: 0.0661
# Epoch 86/100
# 29/29 [==============================] - 0s 611us/step - loss: 0.0660
# Epoch 87/100
# 29/29 [==============================] - 0s 616us/step - loss: 0.0660
# Epoch 88/100
# 29/29 [==============================] - 0s 619us/step - loss: 0.0665
# Epoch 89/100
# 29/29 [==============================] - 0s 599us/step - loss: 0.0673
# Epoch 90/100
# 29/29 [==============================] - 0s 612us/step - loss: 0.0655
# Epoch 91/100
# 29/29 [==============================] - 0s 603us/step - loss: 0.0653
# Epoch 92/100
# 29/29 [==============================] - 0s 611us/step - loss: 0.0670
# Epoch 93/100
# 29/29 [==============================] - 0s 637us/step - loss: 0.0676
# Epoch 94/100
# 29/29 [==============================] - 0s 606us/step - loss: 0.0655
# Epoch 95/100
# 29/29 [==============================] - 0s 604us/step - loss: 0.0636
# Epoch 96/100
# 29/29 [==============================] - 0s 606us/step - loss: 0.0620
# Epoch 97/100
# 29/29 [==============================] - 0s 622us/step - loss: 0.0631
# Epoch 98/100
# 29/29 [==============================] - 0s 619us/step - loss: 0.0621
# Epoch 99/100
# 29/29 [==============================] - 0s 625us/step - loss: 0.0624
# Epoch 100/100
# 29/29 [==============================] - 0s 599us/step - loss: 0.0638

# %% [markdown]
# ### 4. Evaluate model on test data

# %%
model.evaluate([user_test[:, 1:], restaurant_test[:, 1:]], y_test)
# Out:
# 8/8 [==============================] - 0s 718us/step - loss: 0.1331
# 0.13309697806835175

# %% [markdown]
# ### 5. Test on a new user

# %%
# 'n' stands for 'new'
n_id = 5000
n_latitude = 37.7749
n_longitude = 122.4194
n_smoker = "false"
n_drink_level = "abstemious"
n_dress_preference = "informal"
n_ambience = "?"
n_transport = "car owner"
n_marital_status = "single"
n_hijos = "independent"
n_birth_year = 2004
n_interest = "technology"
n_personality = "hard-worker"
n_religion = "none"
n_activity = "student"
n_weight = 61
n_budget = "medium"
n_height = 1.778
n_cuisines = ["Breakfast-Brunch", "Chinese", "Greek", "Indian-Pakistani", "Thai"]

new_user_features = pd.Series(
    [
        n_id, 
        # n_latitude, 
        # n_longitude, 
        n_smoker, 
        n_drink_level,
        n_dress_preference, 
        n_ambience, 
        n_transport, 
        n_marital_status,
        n_hijos, 
        # n_birth_year, 
        n_interest, 
        n_personality, 
        # n_religion, 
        n_activity, 
        # n_weight, 
        n_budget, 
        # n_height
    ],
    index=USER_FEATURES
)

new_user_arr = np.array(encode_features(pd.DataFrame([new_user_features]), USER_FEATURE_OPTIONS).loc[0])

# %%
# Create as many copies of the user's data as there are restaurants
new_user_matrix = np.tile(new_user_arr, (num_restaurants, 1))

# Run prediction
new_user_pred = predict_ratings(model, new_user_matrix[:, 1:], restaurant_vectors[:, 1:], y_scaler)

# Print out predictions in a table format
sorted_indices = np.argsort(-new_user_pred)
new_user_pred = new_user_pred[sorted_indices]
new_user_restaurants = restaurant_vectors[sorted_indices]
names, cuisines = get_restaurant_names_cuisines(new_user_restaurants[:, 0].astype(int))

display = [["Rating Prediction", "Place ID"]]
for i in range(len(new_user_pred)):
    display.append([
        new_user_pred[i], 
        new_user_restaurants[i, 0], 
        names[i],
        cuisines[i]
    ])
tabulate.tabulate(display, tablefmt='html', headers="firstrow")
# Out:
# 5/5 [==============================] - 0s 753us/step
# '<table>\n<thead>\n<tr><th style="text-align: right;">        </th><th style="text-align: right;">      </th><th>Rating Prediction                                   </th><th>Place ID        </th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;">1.85731 </td><td style="text-align: right;">132955</td><td>emilianos                                           </td><td>Bar_Pub_Brewery </td></tr>\n<tr><td style="text-align: right;">1.81712 </td><td style="text-align: right;">135030</td><td>Preambulo Wifi Zone Cafe                            </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.79969 </td><td style="text-align: right;">132755</td><td>La Estrella de Dimas                                </td><td>Mexican         </td></tr>\n<tr><td style="text-align: right;">1.79603 </td><td style="text-align: right;">135050</td><td>Restaurante la Estrella de Dima                     </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.79603 </td><td style="text-align: right;">135040</td><td>Restaurant los Compadres                            </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.79603 </td><td style="text-align: right;">135076</td><td>Restaurante Pueblo Bonito                           </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.79603 </td><td style="text-align: right;">135048</td><td>Restaurante Bar Fu-hao                              </td><td>Bar             </td></tr>\n<tr><td style="text-align: right;">1.7524  </td><td style="text-align: right;">132754</td><td>Cabana Huasteca                                     </td><td>Mexican         </td></tr>\n<tr><td style="text-align: right;">1.75127 </td><td style="text-align: right;">132768</td><td>Mariscos Tia Licha                                  </td><td>Family          </td></tr>\n<tr><td style="text-align: right;">1.74997 </td><td style="text-align: right;">135054</td><td>Restaurante y Pescaderia Tampico                    </td><td>Seafood         </td></tr>\n<tr><td style="text-align: right;">1.74997 </td><td style="text-align: right;">135079</td><td>Koye Sushi                                          </td><td>Chinese         </td></tr>\n<tr><td style="text-align: right;">1.74997 </td><td style="text-align: right;">135064</td><td>Restaurante El Chivero S.A. de C.V.                 </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.73277 </td><td style="text-align: right;">132715</td><td>tacos de la estacion                                </td><td>Mexican         </td></tr>\n<tr><td style="text-align: right;">1.71286 </td><td style="text-align: right;">132847</td><td>don burguers                                        </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.70839 </td><td style="text-align: right;">132613</td><td>carnitas_mata                                       </td><td>Mexican         </td></tr>\n<tr><td style="text-align: right;">1.70754 </td><td style="text-align: right;">135045</td><td>Restaurante la Gran Via                             </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.70715 </td><td style="text-align: right;">132854</td><td>Sirlone                                             </td><td>International   </td></tr>\n<tr><td style="text-align: right;">1.70715 </td><td style="text-align: right;">135001</td><td>Vips                                                </td><td>?               </td></tr>\n<tr><td style="text-align: right;">1.70672 </td><td style="text-align: right;">132862</td><td>La Posada del Virrey                                </td><td>International   </td></tr>\n<tr><td style="text-align: right;">1.69802 </td><td style="text-align: right;">132958</td><td>tacos los volcanes                                  </td><td>American        </td></tr>\n<tr><td style="text-align: right;">1.69667 </td><td style="text-align: right;">132717</td><td>tortas hawai              ...
